# %% [markdown]
# ### Lab 2 ( Julia Lundstrum)
#
# 1) Please watch recitation videos by TAs and my lecture video on Jupyternotebook before doing this lab.
#
# 2) After finishing the lab, save files as html and ipynb.
#
# 3) To submit HW solutions, go to our course in Canvas --> Assignments --> Lab 2 --> Submit Assignment --> Click "Chose file" --> choose HTML file you saved --> Click another file--> choose ipynb file--submit.
#
# 4) Once you submit, download,  and check to make sure that you have submitted the correct files.
#
# 5) When workingfor the solutions to this lab, please do not display unnecessary data unless it is asked.
#
# 6) Please do not share codes or the solutions in the piazza. We can still ask and clarify questions.
#
# 7) Private messages to your Instructors and TAs should be used to ask questions about codes and other details.
#
# 8) Each problem is worth 10 points.

# %% [markdown]
# ### Visualization Basics

# %%
#Useful packages
import pandas as pd
import numpy as np
# The following are mainly for visualization
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Problem 1
# Upload the titanic data set you used for lab 1. Make a new data frame using only the columns 'pclass', 'survived', 'name', 'sex', 'sibsp', 'parch', 'ticket','fare', 'embarked' and name it as newdf. Drop all the null values to clean the data. Print the sum of all the null values for each variable to ensure that the null values are removed. Report the dimension of the cleaned data.

# %%
titanic = pd.read_csv('titanic.csv', decimal = ',')
newcols = titanic[["pclass","survived","name","sex","sibsp","parch","ticket","fare","embarked"]]
new_df = newcols.copy()
new_df = new_df.dropna()
new_df.isna().sum()
# Out:
# pclass      0
# survived    0
# name        0
# sex         0
# sibsp       0
# parch       0
# ticket      0
# fare        0
# embarked    0
# dtype: int64

# %%
new_df.shape
# Out:
# (1306, 9)

# %% [markdown]
# ### Problem 2 (Bar chart)
# a) Draw a vertical bar chart of the pclass variable with pclass in the x-axis and counts in the y-axis. Make a one-sentence comment about your plot. Read more about the bar chart here. https://dfrieds.com/data-visualizations/bar-plot-python-pandas.html
#
# b) Draw a horizontal bar chart of the embarked variable with embarked labels on the y-axis and counts on the x-axis. Make a one-sentence comment about your plot.

# %%
new_df['pclass'].value_counts().plot(kind='bar')

# %% [markdown]
# In the new_df dataset, there are the most people in third class with approximately 700 passengers, then first class with approximately 300 passengers, and the least amount of people in second class with only approximately 250 passengers

# %%
new_df['embarked'].value_counts().plot(kind='barh')
plt.xlabel("Number of passengers")
plt.ylabel("Point of Embarkation")
# Out:
# Text(0, 0.5, 'Point of Embarkation')

# %% [markdown]
# In the new_df dataset, the most passengers boarded at Southampton with approximately 900 passengers, then Cherbourg with approximately 300 passengers, and the least amount of passengengers embarked in Queenstown

# %% [markdown]
# ### Problem 3 (Pie chart)
# a) Do problem 2(a) with a pie chart. Also, plot the % numbers in each piece of the pie.
#
# b) Do problem 2(b) with a pie chart. Also, plot the % numbers in each piece of the pie.

# %%
new_df['pclass'].value_counts().plot(kind='pie', autopct='%1.1f%%')

# %%
new_df['embarked'].value_counts().plot(kind='pie', autopct='%1.1f%%')

# %% [markdown]
# ### Problem 4 (Histogram)
# a) Draw histogram of the age variable from the original data with ten bins. Explain the graph. Some hints are here. https://mode.com/example-gallery/python_histogram/
#
# b) Draw a histogram of the variable fare from the cleaned dataset. Try a various number of bins and see how the histogram looks like. Choose a number of bins that you think is appropriate. Explain the process.

# %%
titanic.age = titanic.age.astype(float)
titanic.hist(column='age',bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11cd07f70>]],
#       dtype=object)

# %% [markdown]
# The distribution of age is skewed right. The most passengers were between the ages of 20 and 30.

# %%
new_df.fare = new_df.fare.astype(float)
new_df.hist(column='fare',bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11ce1fb50>]],
#       dtype=object)

# %% [markdown]
# A majority of people paid a very similar fare, but four people paid over $500, which makes the histogram look strange when you don't remove the outliers. I ended up going with 50 because it shows some variance, but doesn't spread it up too much where you can't see the individual bars.

# %% [markdown]
# ### Problem 5 (Scatter plot and line graph)
# a) Create a scatter plot of age (in x-axis) and fare (in the y-axis) and use the categorize function to color survived variable differently for different values.
#
# b) Use the age variable again to draw a KDE line graph. Find what a KDE graph and explain it it is showing here.

# %%
titanic.fare = titanic.fare.astype(float)
titanic.plot.scatter(x='age',y='fare',c='survived',colormap='coolwarm')

# %%
sns.kdeplot(titanic['age'])

# %% [markdown]
# KDE line graphs is a graph that shows the probability density of variables.
