# %% [markdown]
# # HW1 - Julia Lundstrum

# %% [markdown]
# ## Instructions

# %% [markdown]
# 1) Start the first cell with your name, HW/Lab number, etc. For example, HW1_solutions_basnet.
#
# 2) After you finish the HW, click File on the top left and click "download as." You will see many options. Please save the file as .ipynb and .html file.
#
# 3) To submit HW solutions, go to our course in Canvas --> Assignments --> HW 1 --> Submit Assignment --> Click "Chose file" --> choose HTML file you saved --> Click another file--> choose ipynb file--submit. Once you submit, download  and check to make sure that you have submitted the correct files.
#
# 4) Your submission will be compared against other student's solutions and online databases to check plagiarism.
#
# 5) You can use this ipynb file to start your solution.

# %% [markdown]
# #### Each problem is worth 10 points.

# %%
#import packages
import pandas as pd
import numpy as np

# %% [markdown]
# ### Problem 1.
# Upload the world_countries CSV data and remove all the null values. Change the names of the columns Area_in_sqrmiles, Pop. Density (per sq. mi.)", Infant mortality (per 1000 births), GDP ($ per capita) and Literacy (\%) to Area, Density, Infant_Mortality, GDP, and Literacy respectively.

# %%
wc = pd.read_csv('world_countries.csv', decimal = ',')
wc = wc.dropna()
wc = wc.rename(columns={'Area_in_sqrmiles':'Area','Pop. Density (per sq. mi.)':'Density','Infant mortality (per 1000 births)':'Infant_Mortality','GDP ($ per capita)':'GDP','Literacy (%)':'Literacy'})

# %% [markdown]
# ### Problem 2.
# Use grroupby and mean function to find the following: (a) Regions with maximum and minimum population density. (b). List the regions with an average literacy rate that is less than the average literacy of the world countries? (c). Find and display how many countries does each region has?

# %%
reggrp = wc.groupby('Region')
reggrp.mean()
# Out:
#                                        Population          Area      Density  \
# Region
# ASIA (EX. NEAR EAST)                 1.317137e+08  8.248826e+05  1264.825000
# BALTICS                              2.394991e+06  5.833833e+04    39.833333
# C.W. OF IND. STATES                  2.334013e+07  1.841737e+06    56.708333
# EASTERN EUROPE                       1.231617e+07  1.173192e+05   103.025000
# LATIN AMER. & CARIB                  1.276627e+07  4.668676e+05   138.004545
# NEAR EAST                            1.365565e+07  3.106690e+05   174.614286
# NORTHERN AFRICA                      3.222682e+07  1.150578e+06    46.520000
# NORTHERN AMERICA                     8.290399e+07  4.904096e+06   326.075000
# OCEANIA                              2.160752e+06  5.659993e+05    91.393333
# SUB-SAHARAN AFRICA                   1.498472e+07  4.868206e+05    83.348000
# WESTERN EUROPE                       1.721882e+07  1.612307e+05   907.739130
#
#                                      Infant_Mortality           GDP  \
# Region
# ASIA (EX. NEAR EAST)                        41.780000   8053.571429
# BALTICS                                      8.103333  11300.000000
# C.W. OF IND. STATES                         44.410000   4000.000000
# EASTERN EUROPE                              12.600000  11175.000000
# LATIN AMER. & CARIB                         20.366818   8488.636364
# NEAR EAST                                   23.677857  11850.000000
# NORTHERN AFRICA                             30.916000   5460.000000
# NORTHERN AMERICA                             6.830000  27625.000000
# OCEANIA                                     18.938667  10393.333333
# SUB-SAHARAN AFRICA                          80.392000   2318.000000
# WESTERN EUROPE                               4.573913  28347.826087
#
#                                       Literacy  Birthrate  Deathrate
# Region
# ASIA (EX. NEAR EAST)                 79.553571  21.157857   7.637143
# BALTICS                              99.733333   9.343333  12.630000
# C.W. OF IND. STATES                  98.725000  17.855833  10.341667
# EASTERN EUROPE                       97.600000  10.330000  10.830000
# LATIN AMER. & CARIB                  90.654545  19.197500   6.374773
# NEAR EAST                            79.521429  23.527857   4.945000
# NORTHERN AFRICA                      67.240000  20.814000   4.806000
# NORTHERN AMERICA                     97.750000  12.460000   7.657500
# OCEANIA                              91.013333  20.904000   5.627333
# SUB-SAHARAN AFRICA                   62.510000  35.945800  15.309200
# WESTERN EUROPE                       98.391304  10.502174   9.280000

# %%
wc.mean()
# Out:
# Population          3.153934e+07
# Area                6.461712e+05
# Density             3.568413e+02
# Infant_Mortality    3.711786e+01
# GDP                 9.698058e+03
# Literacy            8.288932e+01
# Birthrate           2.231917e+01
# Deathrate           9.369709e+00
# dtype: float64

# %%
reggrp.size()
# Out:
# Region
# ASIA (EX. NEAR EAST)                   28
# BALTICS                                 3
# C.W. OF IND. STATES                    12
# EASTERN EUROPE                          8
# LATIN AMER. & CARIB                    44
# NEAR EAST                              14
# NORTHERN AFRICA                         5
# NORTHERN AMERICA                        4
# OCEANIA                                15
# SUB-SAHARAN AFRICA                     50
# WESTERN EUROPE                         23
# dtype: int64

# %% [markdown]
# (a) Maximum population density for a region is 1264.825 by Asia (ex. near east).  Minimum population density for a region is 39.8333333 by Baltics.
# (b) The average literacy rate of the world is 82.89% according to this data. Asia (ex. near east), Near East, Northern Africa, and Sub-saharan aftrica have literacy rates lower than the world average.
# (c) Refer to the data generated by reggrp.size()

# %% [markdown]
# ### Problem 3.
# (a) Use nlargest function to find out ten rows that have the largest Infant_Mortality rate. Make some comments about the data that you see. (b) Do the same as in (a) with nsmallest function and Literacy column.

# %%
wc.nlargest(10, 'Infant_Mortality')
# Out:
#             Country                               Region  Population     Area  \
# 5           Angola   SUB-SAHARAN AFRICA                     12127071  1246700
# 0      Afghanistan         ASIA (EX. NEAR EAST)             31056997   647500
# 183   Sierra Leone   SUB-SAHARAN AFRICA                      6005250    71740
# 142     Mozambique   SUB-SAHARAN AFRICA                     19686505   801590
# 117        Liberia   SUB-SAHARAN AFRICA                      3042004   111370
# 151          Niger   SUB-SAHARAN AFRICA                     12525094  1267000
# 128           Mali   SUB-SAHARAN AFRICA                     11716829  1240000
# 188        Somalia   SUB-SAHARAN AFRICA                      8863338   637657
# 199     Tajikistan                  C.W. OF IND. STATES      7320815   143100
# 87   Guinea-Bissau   SUB-SAHARAN AFRICA                      1442029    36120
#
#      Density  Infant_Mortality     GDP  Literacy  Birthrate  Deathrate
# 5        9.7            191.19  1900.0      42.0      45.11      24.20
# 0       48.0            163.07   700.0      36.0      46.60      20.34
# 183     83.7            143.64   500.0      31.4      45.76      23.03
# 142     24.6            130.79  1200.0      47.8      35.18      21.35
# 117     27.3            128.87  1000.0      57.5      44.77      23.10
# 151      9.9            121.69   800.0      17.6      50.73      20.91
# 128      9.5            116.79   900.0      46.4      49.82      16.89
# 188     13.9            116.70   500.0      37.8      45.13      16.63
# 199     51.2            110.76  1000.0      99.4      32.65       8.25
# 87      39.9            107.17   800.0      42.4      37.22      16.53

# %%
wc.nsmallest(10, 'Literacy')
# Out:
#            Country                               Region  Population     Area  \
# 151         Niger   SUB-SAHARAN AFRICA                     12525094  1267000
# 31   Burkina Faso   SUB-SAHARAN AFRICA                     13902972   274200
# 183  Sierra Leone   SUB-SAHARAN AFRICA                      6005250    71740
# 86         Guinea   SUB-SAHARAN AFRICA                      9690222   245857
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997   647500
# 188       Somalia   SUB-SAHARAN AFRICA                      8863338   637657
# 73    Gambia, The   SUB-SAHARAN AFRICA                      1641564    11300
# 180       Senegal   SUB-SAHARAN AFRICA                     11987121   196190
# 97           Iraq   NEAR EAST                              26783383   437072
# 21          Benin   SUB-SAHARAN AFRICA                      7862944   112620
#
#      Density  Infant_Mortality     GDP  Literacy  Birthrate  Deathrate
# 151      9.9            121.69   800.0      17.6      50.73      20.91
# 31      50.7             97.57  1100.0      26.6      45.62      15.60
# 183     83.7            143.64   500.0      31.4      45.76      23.03
# 86      39.4             90.37  2100.0      35.9      41.76      15.48
# 0       48.0            163.07   700.0      36.0      46.60      20.34
# 188     13.9            116.70   500.0      37.8      45.13      16.63
# 73     145.3             72.02  1700.0      40.1      39.37      12.25
# 180     61.1             55.51  1600.0      40.2      32.78       9.42
# 97      61.3             50.25  1500.0      40.4      31.98       5.37
# 21      69.8             85.00  1100.0      40.9      38.85      12.22

# %% [markdown]
# (a) Most of the countries are located in sub-saharan Africa. They also have low gdps and literacy, but have high birth and death rates.
# (b) Most of these countries are also in sub-saharan Africa. They also have low gdps, but have high infant mortality, birth, and death rates.

# %% [markdown]
# ### Problem 4.
# (a) Which countries have a perfect literacy score and a population of 100 million or more? Comment on the answer you get.

# %%
wc.loc[(wc['Population']>100000000) & (wc['Literacy'] == 100)]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Population, Area, Density, Infant_Mortality, GDP, Literacy, Birthrate, Deathrate]
# Index: []

# %% [markdown]
# There aren't any countries that both have a population of greater than 100 million and a perfect literacy test

# %%
# Let's load a few more packages mainly for plotting.
import matplotlib as mpl
import matplotlib.pyplot as mpt
import seaborn as sbn
# Plotting will be discussed in next week's lecture.

# %% [markdown]
# ### Problem 5.
# Use plot function to scatter plot with Area in x-axis and population in the y-axis. You will see that one country while having a low area, has an exceptionally high population and one country despite having a very large area has a low population. Name these countries.

# %%
wc.plot.scatter(x='Area', y='Population')

# %% [markdown]
# The country with a low area but high population is India. The country with the large are, but small population is Russia

# %% [markdown]
# ### Problem 6.
# Use plot function to scatter plot with Literacy in x-axis and GDP in the y-axis. Do you agree with the statement: "Countries with higher literacy rates also have higher GDP."

# %%
wc.plot.scatter(x='Literacy', y='GDP')

# %% [markdown]
# There does appear to be some correlation between literacy rates an GDP, but I wouldn't say that is necessarily true since there are quite a few countries with high literacy rates despite lower GDP.

# %% [markdown]
# ### Problem 7.
# (a) Create a new column called "Difference," which is the difference between Birthrate and Deathrate. (b) Which country has the highest rate of population increase?

# %%
wc['Difference']=wc['Birthrate']-wc['Deathrate']
wc.nlargest(10, 'Difference')
# Out:
#                    Country                               Region  Population  \
# 210                Uganda   SUB-SAHARAN AFRICA                     28195754
# 224                 Yemen   NEAR EAST                              21456188
# 178   Sao Tome & Principe   SUB-SAHARAN AFRICA                       193413
# 128                  Mali   SUB-SAHARAN AFRICA                     11716829
# 155                  Oman   NEAR EAST                               3102229
# 45       Congo, Dem. Rep.   SUB-SAHARAN AFRICA                     62660551
# 124            Madagascar   SUB-SAHARAN AFRICA                     18595469
# 31           Burkina Faso   SUB-SAHARAN AFRICA                     13902972
# 151                 Niger   SUB-SAHARAN AFRICA                     12525094
# 46   Congo, Repub. of the   SUB-SAHARAN AFRICA                      3702314
#
#         Area  Density  Infant_Mortality      GDP  Literacy  Birthrate  \
# 210   236040    119.5             67.83   1400.0      69.9      47.35
# 224   527970     40.6             61.50    800.0      50.2      42.89
# 178     1001    193.2             43.11   1200.0      79.3      40.25
# 128  1240000      9.5            116.79    900.0      46.4      49.82
# 155   212460     14.6             19.51  13100.0      75.8      36.24
# 45   2345410     26.7             94.69    700.0      65.5      43.69
# 124   587040     31.7             76.83    800.0      68.9      41.41
# 31    274200     50.7             97.57   1100.0      26.6      45.62
# 151  1267000      9.9            121.69    800.0      17.6      50.73
# 46    342000     10.8             93.86    700.0      83.8      42.57
#
#      Deathrate  Difference
# 210      12.24       35.11
# 224       8.30       34.59
# 178       6.47       33.78
# 128      16.89       32.93
# 155       3.81       32.43
# 45       13.27       30.42
# 124      11.11       30.30
# 31       15.60       30.02
# 151      20.91       29.82
# 46       12.93       29.64

# %% [markdown]
# Uganda has the highest rate of population increase.

# %% [markdown]
# ### Problem 8.
# Continuing with the Difference variable, (a) Are there countries with a declining population? (b) Can you say the same thing as in (a) about the region?

# %%
wc.nsmallest(10, 'Difference')
# Out:
#            Country                               Region  Population      Area  \
# 26       Botswana   SUB-SAHARAN AFRICA                      1639833    600370
# 211       Ukraine                  C.W. OF IND. STATES     46710816    603700
# 169        Russia                  C.W. OF IND. STATES    142893540  17075200
# 30       Bulgaria   EASTERN EUROPE                          7385367    110910
# 114        Latvia   BALTICS                                 2274735     64589
# 116       Lesotho   SUB-SAHARAN AFRICA                      2022331     30355
# 189  South Africa   SUB-SAHARAN AFRICA                     44187637   1219912
# 138        Monaco   WESTERN EUROPE                            32543         2
# 92        Hungary   EASTERN EUROPE                          9981334     93030
# 64        Estonia   BALTICS                                 1324333     45226
#
#      Density  Infant_Mortality      GDP  Literacy  Birthrate  Deathrate  \
# 26       2.7             54.58   9000.0      79.8      23.08      29.50
# 211     77.4             20.34   5400.0      99.7       8.82      14.39
# 169      8.4             15.39   8900.0      99.6       9.95      14.65
# 30      66.6             20.55   7600.0      98.6       9.65      14.27
# 114     35.2              9.55  10200.0      99.8       9.24      13.66
# 116     66.6             84.23   3000.0      84.8      24.75      28.71
# 189     36.2             61.81  10700.0      86.4      18.20      22.00
# 138  16271.5              5.43  27000.0      99.0       9.19      12.91
# 92     107.3              8.57  13900.0      99.4       9.72      13.11
# 64      29.3              7.87  12300.0      99.8      10.04      13.25
#
#      Difference
# 26        -6.42
# 211       -5.57
# 169       -4.70
# 30        -4.62
# 114       -4.42
# 116       -3.96
# 189       -3.80
# 138       -3.72
# 92        -3.39
# 64        -3.21

# %%
reggrp = wc.groupby('Region')
reggrp.mean()
# Out:
#                                        Population          Area      Density  \
# Region
# ASIA (EX. NEAR EAST)                 1.317137e+08  8.248826e+05  1264.825000
# BALTICS                              2.394991e+06  5.833833e+04    39.833333
# C.W. OF IND. STATES                  2.334013e+07  1.841737e+06    56.708333
# EASTERN EUROPE                       1.231617e+07  1.173192e+05   103.025000
# LATIN AMER. & CARIB                  1.276627e+07  4.668676e+05   138.004545
# NEAR EAST                            1.365565e+07  3.106690e+05   174.614286
# NORTHERN AFRICA                      3.222682e+07  1.150578e+06    46.520000
# NORTHERN AMERICA                     8.290399e+07  4.904096e+06   326.075000
# OCEANIA                              2.160752e+06  5.659993e+05    91.393333
# SUB-SAHARAN AFRICA                   1.498472e+07  4.868206e+05    83.348000
# WESTERN EUROPE                       1.721882e+07  1.612307e+05   907.739130
#
#                                      Infant_Mortality           GDP  \
# Region
# ASIA (EX. NEAR EAST)                        41.780000   8053.571429
# BALTICS                                      8.103333  11300.000000
# C.W. OF IND. STATES                         44.410000   4000.000000
# EASTERN EUROPE                              12.600000  11175.000000
# LATIN AMER. & CARIB                         20.366818   8488.636364
# NEAR EAST                                   23.677857  11850.000000
# NORTHERN AFRICA                             30.916000   5460.000000
# NORTHERN AMERICA                             6.830000  27625.000000
# OCEANIA                                     18.938667  10393.333333
# SUB-SAHARAN AFRICA                          80.392000   2318.000000
# WESTERN EUROPE                               4.573913  28347.826087
#
#                                       Literacy  Birthrate  Deathrate  \
# Region
# ASIA (EX. NEAR EAST)                 79.553571  21.157857   7.637143
# BALTICS                              99.733333   9.343333  12.630000
# C.W. OF IND. STATES                  98.725000  17.855833  10.341667
# EASTERN EUROPE                       97.600000  10.330000  10.830000
# LATIN AMER. & CARIB                  90.654545  19.197500   6.374773
# NEAR EAST                            79.521429  23.527857   4.945000
# NORTHERN AFRICA                      67.240000  20.814000   4.806000
# NORTHERN AMERICA                     97.750000  12.460000   7.657500
# OCEANIA                              91.013333  20.904000   5.627333
# SUB-SAHARAN AFRICA                   62.510000  35.945800  15.309200
# WESTERN EUROPE                       98.391304  10.502174   9.280000
#
#                                      Difference
# Region
# ASIA (EX. NEAR EAST)                  13.520714
# BALTICS                               -3.286667
# C.W. OF IND. STATES                    7.514167
# EASTERN EUROPE                        -0.500000
# LATIN AMER. & CARIB                   12.822727
# NEAR EAST                             18.582857
# NORTHERN AFRICA                       16.008000
# NORTHERN AMERICA                       4.802500
# OCEANIA                               15.276667
# SUB-SAHARAN AFRICA                    20.636600
# WESTERN EUROPE                         1.222174

# %% [markdown]
# (a) According to this data set, there are several countries with declining populations
# (b) It appears the regions Baltics and Eastern Europe both have declining populations

# %% [markdown]
# ### Problem 9.
# (a) Create a new column called "Class" with the following rules: A country with GDP $\leq$ 15000 - poor, A country with GDP between 15000 to 35000 - middle and the rest of the countries - rich. (b) Find out how many countries are in each class.

# %%
wc['Class'] ="rich"

# %%
wc.loc[(wc.GDP <= 15000)] = wc.replace(['rich'],'poor')

# %%
wc.loc[(wc.GDP > 15000) & (wc.GDP < 35000)] = wc.replace(['rich'], 'middle')

# %% [markdown]
# ### Problem 10.
# (a) Create a bar chart for the Class column with Class labels in the x-axis and the number of countries in the y-axis. Comment on the graph. (b) Create a pie chart for the Class column. (c) Create a kernel density chart.

# %%
wc['Class'].value_counts().plot(kind='bar')

# %%
wc['Class'].value_counts().plot(kind='pie')

# %%
wc.loc[(wc.GDP <= 15000)] = wc.replace(['poor'],1)
wc.loc[(wc.GDP > 15000) & (wc.GDP < 35000)] = wc.replace(['middle'],2)
wc.loc[(wc.GDP >= 35000)] = wc.replace(['rich'],3)
wc['Class'] = wc['Class'].astype(int)

# %%
sbn.kdeplot(wc['Class'], bw = 1)
